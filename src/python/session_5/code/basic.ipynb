# %%
class A:
    def show(self):
        print("am in A")

class B(A):
    pass

class C():
    def show(self):
        print("C")

class D(B,C):
    pass

x=D()
x.show()
# Out:
# am in A

# %%
import os

# %%
base="D:/depi/AMIT_GIZ4_AIS2_S1/src/python/session_5"
type(base)
# Out:
# str

# %%
file=os.listdir(base)
print(file)
# Out:
# ['assignment', 'code', 'materials']

# %%
os.remove(base+'/extra file.txt')

# %%
print(file)
# Out:
# ['assignment', 'code', 'materials']

# %%
newFile=base+'/code2'

if not os.path.exists(newFile):
    os.makedirs(newFile)
else:
    print("exists" ,newFile)
# Out:
# exists D:/depi/AMIT_GIZ4_AIS2_S1/src/python/session_5/code2

# %%
with open('D:/depi/AMIT_GIZ4_AIS2_S1/src/python/session_5/code/text.txt','a+') as file:
    file.write("new line added /n")
    file.seek(0)
    new_content=file.read()
    print(new_content)
# Out:
# <built-in method fileno of _io.TextIOWrapper object at 0x00000194A33E0740>

# %%
file=open('D:/depi/AMIT_GIZ4_AIS2_S1/src/python/session_5/code/text.txt','xt+')

# %%
import random
from prettytable import PrettyTable
u='test'
p='0000'
while True:
    x=input("enter user")
    if x == u:
        y=input("enter password")
        if y==p:
            v=random.randrange(10000,1000000)
            print("verification Code: ",v)
            while True:
                l=int(input("Enter V Code: "))
                if l==v:
                    print("access granted")
                    break
                else :
                    print("invalid Verificatoin Code")
                break
        else:
            print("incorrect password")
            continue     
    else:
        print("invalid UserName")
        continue
# Out:
# invalid UserName
# invalid UserName
# invalid UserName
# invalid UserName
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 6
#       4 p='0000'
#       5 while True:
# ----> 6     x=input("enter user")
#       7     if x == u:
#       8         y=input("enter password")
#
# File d:\depi\AMIT_GIZ4_AIS2_S1\.env\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# ...

# %% [markdown]
# Does air quality improve in cities with higher green space coverage per capita? | How does temperature variation correlate with electricity consumption across major cities? | Are air pollution levels significantly lower on weekends compared to weekdays?
