# %%
# %pip install numpy
import numpy as np
# !pip install numby

# %%
v1=np.array([2,3,4])
v2=np.array([3,45,5])
v1.shape
# Out:
# (3,)

# %%
v1.dot(v2)
# Out:
# np.int64(161)

# %%
m1=np.array=([[1,23,4],
     [3,'4',6],
     [5,7,8]])

f=m1.astype(float)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       1 m1=np.array=([[1,23,4],
#       2      [3,'4',6],
#       3      [5,7,8]])
# ----> 5 f=m1.astype(float)
#       6 f
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
x=np.array([1,2,3,4,5,8,7,8])
mat=x.reshape((4,2))
mat
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 8],
#        [7, 8]])
